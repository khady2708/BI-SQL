# %%
import pandas as pd

# %%
pesee = pd.read_csv('./data/pese.csv', sep = ';')
pesee
# Out:
# /tmp/ipykernel_34460/44234400.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pesee = pd.read_csv('./data/pese.csv', sep = ';')
#         PES_NUMERO PES_DATE_ENTREE PES_HEURE_ENTREE PES_DATE_SORTIE  \
# 0          1553784      02/04/2024            10:41      02/04/2024
# 1          1553785      02/04/2024            10:42      02/04/2024
# 2          1553786      02/04/2024            10:43      02/04/2024
# 3          1553787      02/04/2024            10:46      02/04/2024
# 4          1553788      02/04/2024            10:49      02/04/2024
# ...            ...             ...              ...             ...
# 289180     1031979      16/10/2023            08:41      16/10/2023
# 289181     1031980      16/10/2023            08:50      16/10/2023
# 289182     1031981      16/10/2023            08:56      16/10/2023
# 289183     1031982      16/10/2023            09:27      16/10/2023
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
caracterisation= pd.read_csv('./data/caracterisations_2023.csv',sep = ';', encoding='latin1')
caracterisation
# Out:
#       FIQ_ORDRE  FIQ_PES  FIQ_TRA_CODE FIQ_DATE_DEPOT FIQ_DATE_TRI  \
# 0         16990  1527891        116011       27/07/23     27/07/23
# 1         16990  1527891        116011       27/07/23     27/07/23
# 2         16990  1527891        116011       27/07/23     27/07/23
# 3         16990  1527891        116011       27/07/23     27/07/23
# 4         16990  1527891        116011       27/07/23     27/07/23
# ...         ...      ...           ...            ...          ...
# 8934      17055  1535579        330042       16/10/23     16/10/23
# 8935      17055  1535579        330042       16/10/23     16/10/23
# 8936      17055  1535579        330042       16/10/23     16/10/23
# 8937      17055  1535579        330042       16/10/23     16/10/23
# 8938      17055  1535579        330042       16/10/23     16/10/23
#
#                                           MATERIAUX POIDS_VRAC  POIDS_SAC  \
# 0                                Matériaux hors PTM          0          0
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_commune_xlsx = pd.read_excel('data/collecte_2023.xlsx')

df_commune_xlsx.to_csv('data/collecte_2023.csv')

# %% [markdown]
# ![Screenshot from 2024-10-09 11-45-36.png](<attachment:Screenshot from 2024-10-09 11-45-36.png>)

# %%
levee= pd.read_excel('./data/levees_2023.xlsx')
levee
# Out:
#             IMMAT DATE_LEVEE  CODE_CIRCUIT  CODE_INSEE  NB_LEVEES
# 0      nczhm372sk 2023-10-04        120025     38059.0        263
# 1      uqvjh3gzxu 2023-10-18        120001     38059.0        184
# 2      uqvjh3gzxu 2023-06-21        120001     38059.0        199
# 3      uqvjh3gzxu 2023-10-04        120001     38059.0        182
# 4      uqvjh3gzxu 2023-10-11        120001     38059.0        200
# ...           ...        ...           ...         ...        ...
# 19813  oxe1pddfqt 2023-10-20        120066     38158.0          1
# 19814  oxe1pddfqt 2023-12-05        120065     38158.0          1
# 19815  oxe1pddfqt 2023-12-12        120065     38158.0          1
# 19816  a4rn5sg8yd 2023-12-21        120045     38158.0          1
# 19817  jvdwb1fexp 2023-11-24        110006     38158.0          1
#
# [19818 rows x 5 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
commune= pd.read_csv('./data/commune.csv',sep = ',')
commune.head(5)
# Out:
#    CODE_INSEE       NOM_COMMUNE  POPULATION_TOTALE
# 0       38057           BRESSON                699
# 1       38059  BRIE-ET-ANGONNES               2598
# 2       38068       CHAMPAGNIER               1256
# 3       38071    CHAMP-SUR-DRAC               3041
# 4       38111             CLAIX               8129

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Transporteur = pd.read_csv('./data/transporteur.csv', sep = ',', encoding='latin1')
Transporteur
# Out:
#      CODE_TRANSPORTEUR MODALITE_COLLECTE NATURE_COLLECTE SECTEUR_COLLECTE
# 0                  426               PAV      Prestation     MULTISECTEUR
# 1                  881               PAV           Régie         NORD-EST
# 2                  882               PAV           Régie         NORD-EST
# 3                  883               PAV           Régie         NORD-EST
# 4                  884               PAV           Régie              SUD
# ..                 ...               ...             ...              ...
# 289             140007               PAP           Régie       NORD-OUEST
# 290             120069               PAP           Régie              SUD
# 291             120070               PAP           Régie              SUD
# 292             160011               PAP           Régie        GRAND SUD
# 293             160012               PAP           Régie        GRAND SUD
#
# [294 rows x 4 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Exemple de vusualisé les donnés d'une circuit
exemple_circuit = pd.read_csv('./data_2024/exemple_circuit.csv', sep = ';', encoding='latin1')
exemple_circuit
# Out:
#                   Date                 Rue   Latitude  Longitude  Vitesse  \
# 0    01/12/23 04:22:05  Inconnu, Sassenage  45.204479   5.686520      NaN
# 1    01/12/23 04:22:05  Inconnu, Sassenage  45.204479   5.686520      NaN
# 2    01/12/23 04:22:05  Inconnu, Sassenage  45.204479   5.686520      NaN
# 3    01/12/23 04:22:05  Inconnu, Sassenage  45.204479   5.686520      NaN
# 4    01/12/23 04:22:05  Inconnu, Sassenage  45.204479   5.686520      NaN
# ..                 ...                 ...        ...        ...      ...
# 820  01/12/23 10:06:38  Inconnu, Sassenage  45.204430   5.686118      6.0
# 821  01/12/23 10:07:09  Inconnu, Sassenage  45.204391   5.686450      0.0
# 822  01/12/23 10:07:33  Inconnu, Sassenage  45.204636   5.686315     15.0
# 823  01/12/23 10:08:03  Inconnu, Sassenage  45.204731   5.686208      0.0
# 824  01/12/23 10:09:29  Inconnu, Sassenage  45.204762   5.686249      NaN
#
#              Etat  Distance Infos
# 0           DEPOT         0   NaN
# ...

# %%
levee = pd.read_excel('data/levees_2023.xlsx')
levee.to_csv('data/levees_2023.csv')
levee
# Out:
#             IMMAT DATE_LEVEE  CODE_CIRCUIT  CODE_INSEE  NB_LEVEES
# 0      nczhm372sk 2023-10-04        120025     38059.0        263
# 1      uqvjh3gzxu 2023-10-18        120001     38059.0        184
# 2      uqvjh3gzxu 2023-06-21        120001     38059.0        199
# 3      uqvjh3gzxu 2023-10-04        120001     38059.0        182
# 4      uqvjh3gzxu 2023-10-11        120001     38059.0        200
# ...           ...        ...           ...         ...        ...
# 19813  oxe1pddfqt 2023-10-20        120066     38158.0          1
# 19814  oxe1pddfqt 2023-12-05        120065     38158.0          1
# 19815  oxe1pddfqt 2023-12-12        120065     38158.0          1
# 19816  a4rn5sg8yd 2023-12-21        120045     38158.0          1
# 19817  jvdwb1fexp 2023-11-24        110006     38158.0          1
#
# [19818 rows x 5 columns]
